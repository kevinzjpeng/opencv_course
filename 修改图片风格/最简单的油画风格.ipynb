# %%
import cv2

import sys
sys.path.append('..')
from opencv_course import ImageUtil

img = cv2.imread("images/baboon.jpg")
dst = cv2.xphoto.oilPainting(img, 10, 1, cv2.COLOR_BGR2Lab)
ImageUtil.imshow([img, dst], columns=2)
