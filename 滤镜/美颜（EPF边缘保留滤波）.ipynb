# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('epf-test.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#dst = cv2.bilateralFilter(img, 0, 100, 15)

# %%
dst = cv2.pyrMeanShiftFiltering(img, 10, 50)

# %%
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(dst)
plt.show()
